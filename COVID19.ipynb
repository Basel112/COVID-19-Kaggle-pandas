# %%
#preprocssing or data analysis
import pandas as pd
##import numpy as np

#visualization
import matplotlib.pyplot as plt
import plotly as px

import seaborn as sns
from matplotlib import style
from matplotlib import rcParams
style.use('bmh')
rcParams["figure.figsize"]=30,10
rcParams["font.size"]=22
# %matplotlib inline

# %%
dataset=pd.read_csv("./Desktop/COVID19/covid_19_clean_complete.csv",parse_dates=["Date"])
dataset
# Out:
#       Province/State         Country/Region        Lat       Long       Date  \
# 0                NaN            Afghanistan  33.939110  67.709953 2020-01-22
# 1                NaN                Albania  41.153300  20.168300 2020-01-22
# 2                NaN                Algeria  28.033900   1.659600 2020-01-22
# 3                NaN                Andorra  42.506300   1.521800 2020-01-22
# 4                NaN                 Angola -11.202700  17.873900 2020-01-22
# ...              ...                    ...        ...        ...        ...
# 49063            NaN  Sao Tome and Principe   0.186400   6.613100 2020-07-27
# 49064            NaN                  Yemen  15.552727  48.516388 2020-07-27
# 49065            NaN                Comoros -11.645500  43.333300 2020-07-27
# 49066            NaN             Tajikistan  38.861000  71.276100 2020-07-27
# 49067            NaN                Lesotho -29.610000  28.233600 2020-07-27
#
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 49068 entries, 0 to 49067
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Province/State  14664 non-null  object
#  1   Country/Region  49068 non-null  object
#  2   Lat             49068 non-null  float64
#  3   Long            49068 non-null  float64
#  4   Date            49068 non-null  datetime64[ns]
#  5   Confirmed       49068 non-null  int64
#  6   Deaths          49068 non-null  int64
#  7   Recovered       49068 non-null  int64
#  8   Active          49068 non-null  int64
#  9   WHO Region      49068 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(4), object(3)
# memory usage: 3.7+ MB

# %%
dataset.isnull().sum()
# Out:
# Province/State    34404
# Country/Region        0
# Lat                   0
# Long                  0
# Date                  0
# Confirmed             0
# Deaths                0
# Recovered             0
# Active                0
# WHO Region            0
# dtype: int64

# %%
dataset.head()
# Out:
#   Province/State Country/Region       Lat       Long       Date  Confirmed  \
# 0            NaN    Afghanistan  33.93911  67.709953 2020-01-22          0
# 1            NaN        Albania  41.15330  20.168300 2020-01-22          0
# 2            NaN        Algeria  28.03390   1.659600 2020-01-22          0
# 3            NaN        Andorra  42.50630   1.521800 2020-01-22          0
# 4            NaN         Angola -11.20270  17.873900 2020-01-22          0
#
#    Deaths  Recovered  Active             WHO Region
# 0       0          0       0  Eastern Mediterranean
# 1       0          0       0                 Europe
# 2       0          0       0                 Africa
# 3       0          0       0                 Europe
# 4       0          0       0                 Africa

# %%
dataset.tail()
# Out:
#       Province/State         Country/Region        Lat       Long       Date  \
# 49063            NaN  Sao Tome and Principe   0.186400   6.613100 2020-07-27
# 49064            NaN                  Yemen  15.552727  48.516388 2020-07-27
# 49065            NaN                Comoros -11.645500  43.333300 2020-07-27
# 49066            NaN             Tajikistan  38.861000  71.276100 2020-07-27
# 49067            NaN                Lesotho -29.610000  28.233600 2020-07-27
#
#        Confirmed  Deaths  Recovered  Active             WHO Region
# 49063        865      14        734     117                 Africa
# 49064       1691     483        833     375  Eastern Mediterranean
# 49065        354       7        328      19                 Africa
# 49066       7235      60       6028    1147                 Europe
# 49067        505      12        128     365                 Africa

# %%
dataset.shape
# Out:
# (49068, 10)

# %%
dataset.dtypes
# Out:
# Province/State            object
# Country/Region            object
# Lat                      float64
# Long                     float64
# Date              datetime64[ns]
# Confirmed                  int64
# Deaths                     int64
# Recovered                  int64
# Active                     int64
# WHO Region                object
# dtype: object

# %%
Country=pd.unique(dataset["Country/Region"])

dataframe=pd.DataFrame(Country)
dataframe
# Out:
#                          0
# 0              Afghanistan
# 1                  Albania
# 2                  Algeria
# 3                  Andorra
# 4                   Angola
# ..                     ...
# 182  Sao Tome and Principe
# 183                  Yemen
# 184                Comoros
# 185             Tajikistan
# 186                Lesotho
#
# [187 rows x 1 columns]

# %%
len(Country)
# Out:
# 187

# %%
Gender=pd.unique(dataset["WHO Region"])
Gender
# Out:
# array(['Eastern Mediterranean', 'Europe', 'Africa', 'Americas',
#        'Western Pacific', 'South-East Asia'], dtype=object)

# %%
length_Gender=len(Gender)
length_Gender
# Out:
# 6

# %%
dataset.describe()
# Out:
#                 Lat          Long                 Date     Confirmed  \
# count  49068.000000  49068.000000                49068  4.906800e+04
# mean      21.433730     23.528236  2020-04-24 12:00:00  1.688490e+04
# min      -51.796300   -135.000000  2020-01-22 00:00:00  0.000000e+00
# 25%        7.873054    -15.310100  2020-03-08 18:00:00  4.000000e+00
# 50%       23.634500     21.745300  2020-04-24 12:00:00  1.680000e+02
# 75%       41.204380     80.771797  2020-06-10 06:00:00  1.518250e+03
# max       71.706900    178.065000  2020-07-27 00:00:00  4.290259e+06
# std       24.950320     70.442740                  NaN  1.273002e+05
#
#               Deaths     Recovered        Active
# count   49068.000000  4.906800e+04  4.906800e+04
# mean      884.179160  7.915713e+03  8.085012e+03
# min         0.000000  0.000000e+00 -1.400000e+01
# 25%         0.000000  0.000000e+00  0.000000e+00
# 50%         2.000000  2.900000e+01  2.600000e+01
# ...

# %%
dataset["Country/Region"].value_counts()
# Out:
# Country/Region
# China             6204
# Canada            2256
# France            2068
# United Kingdom    2068
# Australia         1504
#                   ...
# Holy See           188
# Honduras           188
# Hungary            188
# Iceland            188
# Lesotho            188
# Name: count, Length: 187, dtype: int64

# %% [markdown]
# # DATA VISUALIZATION

# %%
group_by_Date= dataset.groupby("Date").agg({"Confirmed":"sum","Recovered":"sum","Deaths":"sum"}).reset_index()

# %%
group_by_Date
# Out:
#           Date  Confirmed  Recovered  Deaths
# 0   2020-01-22        555         28      17
# 1   2020-01-23        654         30      18
# 2   2020-01-24        941         36      26
# 3   2020-01-25       1434         39      42
# 4   2020-01-26       2118         52      56
# ..         ...        ...        ...     ...
# 183 2020-07-23   15510481    8710969  633506
# 184 2020-07-24   15791645    8939705  639650
# 185 2020-07-25   16047190    9158743  644517
# 186 2020-07-26   16251796    9293464  648621
# 187 2020-07-27   16480485    9468087  654036
#
# [188 rows x 4 columns]

# %%
def graph(X):
    
    x=list(X.index)
    plt.plot(x,X["Confirmed"])
    plt.plot(x,X["Recovered"])
    plt.plot(x,X["Deaths"])
    plt.legend(['Confirmed','Recovered','Deaths'],loc= 'upper left')

# %%
x=list(group_by_Date.index)
graph(group_by_Date)

# %%
group_by_Date.index=pd.to_datetime(group_by_Date["Date"]) ## index by date 

group_by_Month=group_by_Date.groupby(pd.Grouper(freq="M")).agg({"Confirmed":"max","Recovered":"max","Deaths":"max"}).reset_index()

# %%
group_by_Month
# Out:
#         Date  Confirmed  Recovered  Deaths
# 0 2020-01-31       9927        219     213
# 1 2020-02-29      85306      38314    2936
# 2 2020-03-31     871355     174074   44478
# 3 2020-04-30    3268876     989616  234704
# 4 2020-05-31    6185530    2585589  373606
# 5 2020-06-30   10449697    5281459  511210
# 6 2020-07-31   16480485    9468087  654036

# %%
x=list(group_by_Month.index)
plt.xticks(x,group_by_Month["Date"])
graph(group_by_Month)
